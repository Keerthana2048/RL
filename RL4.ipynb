# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthana2048/RL/blob/main/RL4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

class MultiArmedBandit:
  def __init__(self,k =10):

    self.k = k
    self.true_rewards = np.random.normal(0,1,k)
    self.estimates = np.zeros(k)
    self.action_counts = np.zeros(k)
    self.total_steps = 0
  def pull_arm(self, action):
    reward = np.random.normal(self.true_rewards[action],1)
    return reward
  def update_estimates(self, action, reward):
    self.action_counts[action] += 1
    self.estimates[action] += (reward - self.estimates[action])/self.action_counts[action]
  def select_action(self, epsilon):
    if np.random.random() < epsilon:
      return np.random.randint(self.k)
    else:
      action = np.argmax(self.estimates)
      return action

def run_bandit(k = 10, steps = 1000, epsilon = 0.1):
  bandit = MultiArmedBandit(k)
  rewards = []
  for step in range(steps):
    action = bandit.select_action(epsilon)
    reward = bandit.pull_arm(action)
    bandit.update_estimates(action, reward)
    rewards.append(reward)
  return rewards, bandit

rewards, bandit = run_bandit(k=10, steps=1000,epsilon = 0.1)
print(rewards)
# Out:
# [-1.0557575673107527, 0.7866510759939537, -1.3140135630385084, 1.1585101846959733, 0.8504330371737845, 0.47696813662882515, 0.3259119111453169, 1.4509713960080186, 1.3821353387040614, 0.20721214742132477, -0.6500194986457274, 0.9235950106990263, -1.3704179554909866, 1.4274156534516678, 1.4994032566851807, 1.238917688313303, 0.4726453479552836, -0.7099226386429859, 0.17880245791576604, 0.6167892331302671, 1.1397698662494768, -0.5449310879214433, -2.402445399516975, 0.882884031409097, 0.6166348627246736, -0.771841382066263, 0.35538309596277584, 0.7627889725732273, -1.1995111536697705, -0.15509780405714702, -2.0849507345563474, -0.2048026879276037, 3.1538081520359955, 1.5975201062393096, -1.6674729718126462, 1.243935165390854, -0.1215136787149439, 2.151777030724672, 0.23077361078714076, 0.5430146593483307, 1.0457610407260804, 0.31909762340140924, 0.6427614220597007, 1.3744075728378367, -0.7041301087186952, -0.3535001635319909, 0.9061301052649327, -0.8916077420490847, -0.328219162744412, -0.08488052765562382, -0.29926966153624257, 0.0888392551920954, -0.15341916723834192, -0.05042018899338774, -0.4060894510519941, -1.0512509723263035, -0.13212039830896294, -1.1134438378138625, 3.029388105255865, -0.6674950428384675, 1.2073729910370492, -0.030288146929973503, 0.29568071334070206, 0.6302026644951942, -0.2315234677948269, 1.3402226680981102, -0.031166776277150587, 1.0492318828039569, 0.9895466215346349, 0.7604840623131546, 1.4540573851236123, -2.0845983118730826, 1.9